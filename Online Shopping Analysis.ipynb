# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.graph_objects as go

# %%
df = pd.read_csv(r"C:\Users\omare\OneDrive\Documents\anaconda_projects\Training_data_sets\file.csv")
df
# Out:
#        Unnamed: 0  CustomerID Gender Location  Tenure_Months  Transaction_ID  \
# 0               0     17850.0      M  Chicago           12.0         16679.0
# 1               1     17850.0      M  Chicago           12.0         16680.0
# 2               2     17850.0      M  Chicago           12.0         16696.0
# 3               3     17850.0      M  Chicago           12.0         16699.0
# 4               4     17850.0      M  Chicago           12.0         16700.0
# ...           ...         ...    ...      ...            ...             ...
# 52950       52950         NaN    NaN      NaN            NaN             NaN
# 52951       52951         NaN    NaN      NaN            NaN             NaN
# 52952       52952         NaN    NaN      NaN            NaN             NaN
# 52953       52953         NaN    NaN      NaN            NaN             NaN
# 52954       52954         NaN    NaN      NaN            NaN             NaN
#
#       Transaction_Date     Product_SKU  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52955 entries, 0 to 52954
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           52955 non-null  int64
#  1   CustomerID           52924 non-null  float64
#  2   Gender               52924 non-null  object
#  3   Location             52924 non-null  object
#  4   Tenure_Months        52924 non-null  float64
#  5   Transaction_ID       52924 non-null  float64
#  6   Transaction_Date     52924 non-null  object
#  7   Product_SKU          52924 non-null  object
#  8   Product_Description  52924 non-null  object
#  9   Product_Category     52955 non-null  object
#  10  Quantity             52924 non-null  float64
#  11  Avg_Price            52924 non-null  float64
#  12  Delivery_Charges     52924 non-null  float64
#  13  Coupon_Status        52924 non-null  object
#  14  GST                  52924 non-null  float64
# ...

# %%
df.describe(include= 'all')
# Out:
#           Unnamed: 0   CustomerID Gender Location  Tenure_Months  \
# count   52955.000000  52924.00000  52924    52924   52924.000000
# unique           NaN          NaN      2        5            NaN
# top              NaN          NaN      F  Chicago            NaN
# freq             NaN          NaN  33007    18380            NaN
# mean    26477.000000  15346.70981    NaN      NaN      26.127995
# std     15286.936089   1766.55602    NaN      NaN      13.478285
# min         0.000000  12346.00000    NaN      NaN       2.000000
# 25%     13238.500000  13869.00000    NaN      NaN      15.000000
# 50%     26477.000000  15311.00000    NaN      NaN      27.000000
# 75%     39715.500000  16996.25000    NaN      NaN      37.000000
# max     52954.000000  18283.00000    NaN      NaN      50.000000
#
#         Transaction_ID Transaction_Date     Product_SKU  \
# count     52924.000000            52924           52924
# unique             NaN              365            1145
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID              31
# Gender                  31
# Location                31
# Tenure_Months           31
# Transaction_ID          31
# Transaction_Date        31
# Product_SKU             31
# Product_Description     31
# Product_Category         0
# Quantity                31
# Avg_Price               31
# Delivery_Charges        31
# Coupon_Status           31
# GST                     31
# Date                    31
# Offline_Spend           31
# Online_Spend            31
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
df.shape
# Out:
# (52955, 21)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
#        'Transaction_ID', 'Transaction_Date', 'Product_SKU',
#        'Product_Description', 'Product_Category', 'Quantity', 'Avg_Price',
#        'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
#        'Online_Spend', 'Month', 'Coupon_Code', 'Discount_pct'],
#       dtype='object')

# %%
df = df.dropna(subset= ['Unnamed: 0', 'CustomerID', 'Gender', 'Location', 'Tenure_Months',
       'Transaction_ID', 'Transaction_Date', 'Product_SKU',
       'Product_Description', 'Quantity', 'Avg_Price',
       'Delivery_Charges', 'Coupon_Status', 'GST', 'Date', 'Offline_Spend',
       'Online_Spend'])

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# CustomerID               0
# Gender                   0
# Location                 0
# Tenure_Months            0
# Transaction_ID           0
# Transaction_Date         0
# Product_SKU              0
# Product_Description      0
# Product_Category         0
# Quantity                 0
# Avg_Price                0
# Delivery_Charges         0
# Coupon_Status            0
# GST                      0
# Date                     0
# Offline_Spend            0
# Online_Spend             0
# Month                    0
# Coupon_Code            400
# Discount_pct           400
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['unnamed: 0', 'customerid', 'gender', 'location', 'tenure_months',
#        'transaction_id', 'transaction_date', 'product_sku',
#        'product_description', 'product_category', 'quantity', 'avg_price',
#        'delivery_charges', 'coupon_status', 'gst', 'date', 'offline_spend',
#        'online_spend', 'month', 'coupon_code', 'discount_pct'],
#       dtype='object')

# %%
df = df.rename(columns= {'customerid' : 'customer_id'})
df.columns
# Out:
# Index(['unnamed: 0', 'customer_id', 'gender', 'location', 'tenure_months',
#        'transaction_id', 'transaction_date', 'product_sku',
#        'product_description', 'product_category', 'quantity', 'avg_price',
#        'delivery_charges', 'coupon_status', 'gst', 'date', 'offline_spend',
#        'online_spend', 'month', 'coupon_code', 'discount_pct'],
#       dtype='object')

# %%
df.tail(10)
# Out:
#        unnamed: 0  customer_id gender    location  tenure_months  \
# 52914       52914      14031.0      F     Chicago           17.0
# 52915       52915      15002.0      M     Chicago           41.0
# 52916       52916      15002.0      M     Chicago           41.0
# 52917       52917      15002.0      M     Chicago           41.0
# 52918       52918      15002.0      M     Chicago           41.0
# 52919       52919      13155.0      F  California            8.0
# 52920       52920      18077.0      M     Chicago           34.0
# 52921       52921      16085.0      M  California           15.0
# 52922       52922      16085.0      M  California           15.0
# 52923       52923      13659.0      F     Chicago            8.0
#
#        transaction_id transaction_date     product_sku  \
# 52914         19075.0       2019-01-29  GGOEGBPB081999
# 52915         23797.0       2019-03-22  GGOEGGCX056299
# 52916         23798.0       2019-03-22  GGOEGGCX056299
# ...

# %%
df = df.drop(columns= ['unnamed: 0'])

# %%
df['coupon_code'] = df['coupon_code'].fillna('No coupon code provided!')
df['discount_pct'] = df['discount_pct'].fillna(0)

# %%
df.isnull().sum()
# Out:
# customer_id            0
# gender                 0
# location               0
# tenure_months          0
# transaction_id         0
# transaction_date       0
# product_sku            0
# product_description    0
# product_category       0
# quantity               0
# avg_price              0
# delivery_charges       0
# coupon_status          0
# gst                    0
# date                   0
# offline_spend          0
# online_spend           0
# month                  0
# coupon_code            0
# discount_pct           0
# dtype: int64

# %%
df = df.rename(columns= {'product_description' : 'product_name','avg_price' : 'price', 'gst' : 'tax_percentage', 'discount_pct' : 'discount_percentage'})
df.columns
# Out:
# Index(['customer_id', 'gender', 'location', 'tenure_months', 'transaction_id',
#        'transaction_date', 'product_sku', 'product_name', 'product_category',
#        'quantity', 'price', 'delivery_charges', 'coupon_status',
#        'tax_percentage', 'date', 'offline_spend', 'online_spend', 'month',
#        'coupon_code', 'discount_percentage'],
#       dtype='object')

# %%
df['coupon_status'].unique()
# Out:
# array(['Used', 'Not Used', 'Clicked'], dtype=object)

# %%
df['coupon_status'] = df['coupon_status'].str.replace('Clicked', 'Used', regex= True)

# %%
df['coupon_status'].unique()
# Out:
# array(['Used', 'Not Used'], dtype=object)

# %%
df.head()
# Out:
#    customer_id gender location  tenure_months  transaction_id  \
# 0      17850.0      M  Chicago           12.0         16679.0
# 1      17850.0      M  Chicago           12.0         16680.0
# 2      17850.0      M  Chicago           12.0         16696.0
# 3      17850.0      M  Chicago           12.0         16699.0
# 4      17850.0      M  Chicago           12.0         16700.0
#
#   transaction_date     product_sku  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                         product_name product_category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#        customer_id gender    location  tenure_months  transaction_id  \
# 0          17850.0      M     Chicago           12.0         16679.0
# 1          17850.0      M     Chicago           12.0         16680.0
# 2          17850.0      M     Chicago           12.0         16696.0
# 3          17850.0      M     Chicago           12.0         16699.0
# 4          17850.0      M     Chicago           12.0         16700.0
# ...            ...    ...         ...            ...             ...
# 52919      13155.0      F  California            8.0         22504.0
# 52920      18077.0      M     Chicago           34.0         24250.0
# 52921      16085.0      M  California           15.0         39991.0
# 52922      16085.0      M  California           15.0         39991.0
# 52923      13659.0      F     Chicago            8.0         39998.0
#
#       transaction_date     product_sku  \
# 0           2019-01-01  GGOENEBJ079499
# 1           2019-01-01  GGOENEBJ079499
# ...

# %%
import pymysql
import sqlalchemy

# %%
from sqlalchemy import create_engine

# MySQL connection
username = 
password = 
host = 
port = 
database = 

engine = create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# Write DataFrame to MySQL
table_name = "performance"  # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

# Read back sample
pd.read_sql("SELECT * FROM performance LIMIT 5;", engine)
# Out:
#    customer_id gender location  tenure_months  transaction_id  \
# 0      17850.0      M  Chicago           12.0         16679.0
# 1      17850.0      M  Chicago           12.0         16680.0
# 2      17850.0      M  Chicago           12.0         16696.0
# 3      17850.0      M  Chicago           12.0         16699.0
# 4      17850.0      M  Chicago           12.0         16700.0
#
#   transaction_date     product_sku  \
# 0       2019-01-01  GGOENEBJ079499
# 1       2019-01-01  GGOENEBJ079499
# 2       2019-01-01  GGOENEBQ078999
# 3       2019-01-01  GGOENEBQ079099
# 4       2019-01-01  GGOENEBJ079499
#
#                                         product_name product_category  \
# 0  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 1  Nest Learning Thermostat 3rd Gen-USA - Stainle...         Nest-USA
# 2             Nest Cam Outdoor Security Camera - USA         Nest-USA
# 3    Nest Protect Smoke + CO White Battery Alarm-USA         Nest-USA
# ...
